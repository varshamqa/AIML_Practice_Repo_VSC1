# %% [markdown]
# <a href="https://colab.research.google.com/github/varshamqa/AIML_Practice_Repo_VSC1/blob/main/AIML_Langchain_VVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-groq python-dotenv

# %%
import os
import getpass
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# Once you have added the `GROC_API_KEY` to Colab secrets as described above, you can access it in your code:

# %%
from google.colab import userdata

# Correct way to retrieve the secret by its assigned name
try:
    GROC_API_KEY = userdata.get('GROC_API_KEY')
    print("GROC_API_KEY retrieved successfully!")
except userdata.SecretNotFoundError:
    print("Secret GROC_API_KEY is still not found. Please ensure it's added correctly in the Colab secrets panel.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# GROC_API_KEY retrieved successfully!

# %%
llm = ChatGroq(
    model = "llama-3.3-70b-versatile",
    temperature= 0.3,
    api_key=GROC_API_KEY # Pass the retrieved API key
)

# %%
prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """
        You are an expert AI/ML Professor who is well versed with all modern day and traditional AI/ML concepts
        Explain the technical concepts to the students in a simple, lamen way and in a structured manner.
        Follow this format to answer the asked questions:

        1) Definition
        2) Pre-Requisites
        3) Architecture
        4) Core Features
        5) Advantages
        6) Disadvantages
        7) Apllications
        8) One Line Conclusion

        The explanation given should be considered by the fact that the audience is a beginner.
        """
    ),
    (
        "user",
        """
        Explain the following concept:
        {topic}
        """
    )
])

# %%
chain = prompt | llm | StrOutputParser()

# %%
response = chain.invoke({
    "topic": "Agentic AI"
})

# %%
print(response)
# Out:
# Here's an explanation of Agentic AI in a simple and structured manner:
#
# 1. **Definition**: Agentic AI refers to a type of artificial intelligence that enables machines to act autonomously and make decisions based on their own goals, preferences, and motivations. It's like having a personal assistant that can think and act on its own, making decisions that align with its objectives.
#
# 2. **Pre-Requisites**: To understand Agentic AI, you should have a basic knowledge of artificial intelligence, machine learning, and software development. Familiarity with concepts like agent-based modeling, decision-making, and autonomous systems is also helpful.
#
# 3. **Architecture**: The architecture of Agentic AI typically consists of three main components:
# 	* **Perception**: The ability to perceive and understand the environment.
# 	* **Reasoning**: The ability to reason and make decisions based on the perceived information.
# ...
